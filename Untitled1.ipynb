# %%
#Question no:1
print(0.1+0.2)
print("1.8"+"2")
print(87>78)
print((0.1+0.2)==0.3)
print("predict""output",".....")
# Out:
# 0.30000000000000004
# 1.82
# True
# False
# predictoutput .....

# %%
#Questionno:2
print("prints","multiple","messages\n")
print("concatenate"+"two strings\n")
print(5+6+"adds two numbers\n")
#Output: prints multiple messeages
#        concatenate two numbers
#         error:A string and a int cannot be added

# %%
#Question no:3
print("ba"+"na"*2)
print(r'c:\naresh\raju\abhi')
# Out:
# banana
# c:\naresh\raju\abhi

# %%
#Question no:4
str='welcome to python traing program'
print(str[0:32:4])
tr='A series of characters designated as one object known as a string'
tr[2:19:5]
# Out:
# wotyna g
# 'sscc'

# %%
#Question no:5
print('A series of characters designed as one object known as a string'[::1][4::3])
print("----------")
print('welcome to python traing program'[3:10][::-1])
# Out:
# rsfhae sn  ebckwaatn
# ----------
# ot emoc

# %%
#Question no:6a
str1=True
x=5>3
print(str1==x)
y=5>8
print(str1==y)
# Out:
# True
# False

# %%
#Question no:6b
num=7
Name="Michael Jackson"
sear_num=Name.find('el')
print(num>sear_num)
# Out:
# True

# %%
p_phrase="was it a car or a cat I saw".upper()
str1 = p_phrase[::-1]
print(str1)
# Out:
# WAS I TAC A RO RAC A TI SAW

# %%
#Question no:8
a='1934567'
a[1:7:2]
# Out:
# '946'

# %%
#Question no:9
fake_phrase="Fake news has a knack for spreding like wildfire".upper()
out=fake_phrase[-9:14:-1]
out.split()
# Out:
# ['EKIL', 'GNIDERPS', 'ROF', 'KCANK']

# %%
#Question no:10
msg1="facebook already uses AI to filter for spreading like wildfire"
out=msg1.split()
print(out)
# Out:
# ['facebook', 'already', 'uses', 'AI', 'to', 'filter', 'for', 'spreading', 'like', 'wildfire']

# %%
#Question no:11
msg2="welcome to sr engineering college"
x=msg2.count('o')
y=msg2.count('r')
msg2[y**x:(x**y+x+y):][::-1]
# Out:
# ' rs ot'

# %%
#Question no:12a
num1,num2="94","30"
data="As per census 2011,gender ratio of india is 943 females per 1000 males"
num1+num2[0] in data
# Out:
# True

# %%
#Question no:12b
print(data[:45],print(int(num1)+int(num2)))
# Out:
# 124
# As per census 2011,gender ratio of india is 9 None

# %%
#Question no:13
m=int(input("enter amount of water in kg"))
b=int(input("enter initial temperature"))
c=int(input("enter final temperature"))
Q=m*(c-b)*4184
print(Q)
# Out:
# enter amount of water in kg2
# enter initial temperature14
# enter final temperature12
# -16736

# %%
#Question no:14
x=int(input("enter x"))
y=2*x;
z=('z'*x)+('o'*y)
z
# Out:
# enter x5
# 'zzzzzoooooooooo'

# %%
#Question no:15
x=int(input("enter x"))
y=int(input("enter y"))
pow=x**y
d=x*y
div=pow//d
c=x+y
out=div^c
print(pow)
print(div)
print(out)
# Out:
# enter x2
# enter y4
# 16
# 2
# 4
